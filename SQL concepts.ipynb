# %% [markdown]
# # Steps to setup a local MySQL server

# %% [raw]
# 1. follow the steps mentioned in: https://youtu.be/2om3byn2lxs?si=BeDuBpQ6h2eFULCK
# 2. connect to the database using workbench and execute the "" SQL script in the folder of this repo.
# 3. All set!

# %% [markdown]
# # Steps to connect to this locally hosted MySql server

# %%
#Execute to install the connector
# !pip install mysql-connector-python

# %%
import mysql.connector
from mysql.connector import Error
from Credential.credential import user      #should be commented
from Credential.credential import password  #should be commented

# %%
# Connect to local host Instance with orders as the database
try:
    connection = mysql.connector.connect(host='localhost',
                                         database='orders',
                                         user=user,         #Root by default if above steps were followed
                                         password=password) #Configure your root password here. I have used my own
    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)

except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Connected to MySQL Server version  8.0.34
# You're connected to database:  ('orders',)

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
def gd(sql):
    return pd.read_sql(sql,connection)

# %%
# Verify if data is being fetched
gd(
'''
Select * 
from address
limit 1'''
)
# Out:
#    ADDRESS_ID                  ADDRESS_LINE1                 ADDRESS_LINE2  \
# 0         909  H.NO.16, Sector-4, 14th Cross  Near BDA Complex, HSR Layout
#
#         CITY      STATE  PINCODE COUNTRY
# 0  Bangalore  Karnataka   560172   India

# %% [markdown]
# # Glance at the data

# %% [markdown]
# ![image.png](attachment:1cdfbf90-ec6d-4c68-a5b7-aaf993226806.png)

# %%
# List of all columns in the schema
gd('''
select * from information_schema.columns
where table_schema = 'orders'
order by table_name,ordinal_position

''')
# Out:
#    TABLE_CATALOG TABLE_SCHEMA       TABLE_NAME             COLUMN_NAME  \
# 0            def       orders          address              ADDRESS_ID
# 1            def       orders          address           ADDRESS_LINE1
# 2            def       orders          address           ADDRESS_LINE2
# 3            def       orders          address                    CITY
# 4            def       orders          address                   STATE
# 5            def       orders          address                 PINCODE
# 6            def       orders          address                 COUNTRY
# 7            def       orders           carton               CARTON_ID
# 8            def       orders           carton                     LEN
# 9            def       orders           carton                   WIDTH
# 10           def       orders           carton                  HEIGHT
# 11           def       orders  online_customer             CUSTOMER_ID
# ...

# %%
gd('''show tables''')
# Out:
#   Tables_in_orders
# 0          address
# 1           carton
# 2  online_customer
# 3     order_header
# 4      order_items
# 5          product
# 6    product_class
# 7          shipper

# %% [markdown]
# # Overview of Objectives

# %%
# Concepts to learn:
# Assuming the user is using this as a revision of SQL and is aware of basic select query structure

# %% [raw]
# 1.  Data types & variables
# 2.  Select, Where, And, Or, Not, Order By, commands.
# 3.  Insert, Update, Delete commands.
# 4.  Min, Max, Count, Average, Sum, commands.
# 5.  Like, In, Between, Top, Group By, commands.
# 6.  Joins such as Inner, Outer, Left, Right, Full, Self joins.
# 7.  SQL having, exists, any, all, case, null functions, etc.
# 8.  SQL database-related commands such as create, drop, backup, etc.
# 9.  SQL table commands such as create, alter, update, drop, etc.
# 10. SQL constraints such as not null, unique, check, default, auto-increment, etc.
# 11. SQL keys such as primary, unique, foreign, etc.
# 12. SQL advanced concepts such as Views, Triggers, Functions, PL/SQL, Injection, Hosting, etc. #Currently out of Scope
